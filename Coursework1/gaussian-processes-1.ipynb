# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import LinearColorMapper, BasicTicker, ColorBar
from bokeh.palettes import Category10
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9fb903e4-ec68-4797-9c66-4cc65d4a93aa">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Introduction to Gaussian Processes - Part I
# Author: [@alex_bridgland](https://twitter.com/alex_bridgland) | [@bridgo](https://github.com/Bridgo)
#
# Blog post: http://bridg.land/posts/gaussian-processes-1
# ***
# Gaussian processes may not be at the center of current machine learning hype but are still used at the forefront of research -- they were recently seen automatically tuning the MCTS hyperparameters for AlphaGo Zero for instance. They manage to be very easy to use while providing rich modeling capacity and uncertainty estimates.
#
# However they can be pretty hard to grasp, especially if you're used to the type of models we see a lot of in deep learning. So hopefully this guide can fix that! It assumes a fairly minimal ML background and I aimed for a more visual & intuitive introduction without totally abandoning the theory. To get the most out of it I recommend downloading the notebook and experimenting with all the code!
#
# ## What is a Gaussian Process and why would I use one?
# ***
# A Gaussian process (GP) is a powerful model that can be used to represent a distribution over functions. Most modern techniques in machine learning tend to avoid this by parameterising functions and then modeling these parameters (e.g. the weights in linear regression). However GPs are nonparametric models that model the function directly. This comes with one hugely important benefit: not only can we model any black-box function, __we can also model our uncertainty__. Quantifying uncertainty can be extremely valuable - for example if we are allowed to explore (request more data) we can chose to explore the areas we are least certain about to be as efficient as possible. This is the main idea behind Bayesian optimisation. For more information on the importance of uncertainty modeling see [this article](http://mlg.eng.cam.ac.uk/yarin/blog_3d801aa532c1ce.html) by Yarin Gal.
#
# > If you give me several pictures of cats and dogs – and then you ask me to classify a new cat photo – I should return a prediction with rather high confidence. But if you give me a photo of an ostrich and force my hand to decide if it's a cat or a dog – I better return a prediction with very low confidence.
# >
# > Yarin Gal
#
# For this introduction we will consider a simple regression setup without noise (but GPs can be extended to multiple dimensions and noisy data):
# - We assume there is some hidden function $f:\mathbb{R}\rightarrow\mathbb{R}$ that we want to model.
# - We have data $\mathbf{x}=[x_ 1, \ldots, x_N]^T, \mathbf{y}=[y_ 1, \ldots, y_N]^T$ where $y_i = f(x_i)$.
# - We want to predict the value of $f$ at some new, unobserved points $\mathbf{x}_*$.
#
# ## Modeling Functions using Gaussians
# ***
# The key idea behind GPs is that a function can be modeled using an infinite dimensional multivariate Gaussian distribution. In other words, every point in the input space is associated with a random variable and the joint distribution of these is modeled as a multivariate Gaussian.
#
# Ok, so what does that mean and what does it actually look like? Well lets start with a simpler case: a unit 2D Gaussian. How can we start to view this as a distribution over functions? Here's what we have:
#
# $$ \begin{pmatrix} y_0 \\ y_1 \end{pmatrix} \sim\mathcal{N}\left(\begin{pmatrix} 0\\ 0 \end{pmatrix}, \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}\right) $$
#
# Normally this is visualised as a 3D bell curve with the probability density represented as height. But what if, instead of visualising the whole distribution, we just sample from the distribution. Then we will have two values which we can plot on an graph. Let's do this 10 times, putting the first value at $x=0$ and the second at $x=1$ and then drawing a line between them.

# %%
def plot_unit_gaussian_samples(D):
    p = figure(plot_width=800, plot_height=500, title='Samples from a unit {}D Gaussian'.format(D))

    xs = np.linspace(0, 1, D)
    for color in Category10[10]:
        ys = np.random.multivariate_normal(np.zeros(D), np.eye(D))
        p.line(xs, ys, line_width=1, color=color)
    return p

# %%
show(plot_unit_gaussian_samples(2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"LinearAxis"},{"attributes":{"callback":null},"id":"ad47a35b-eca6-4c05-a50b-3f8fffda0b36","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9cb23a8f-3c15-4e8c-8a43-2f48482676ff","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f4ac0af-512d-497e-859a-0291dbd63466","type":"Line"},{"attributes":{},"id":"e1d8cf0f-99b7-400a-8ee7-733c8dab25b3","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#7f7f7f"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f445cbb8-976f-4e93-ade9-bca5aed067f0","type":"Line"},{"attributes":{"line_color":{"value":"#bcbd22"},"x":{"field":"x"},"y":{"field":"y"}},"id":"197dc718-77cb-4974-a96d-5c7a0acd8334","type":"Line"},{"attributes":{"formatter":{"id":"4f7949bd-63ad-4d00-b5ff-98e90703d167","type":"BasicTickFormatter"},"plot":{"id":"beae101c-d8ae-4dc4-b7cb-3f0c3589f8a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1d8cf0f-99b7-400a-8ee7-733c8dab25b3","type":"BasicTicker"}},"id":"d8370ef3-41bc-4eab-9b8b-6ef3a6ca977f","type":"LinearAxis"},{"attributes":{"data_source":{"id":"fc0b66fb-a134-47e8-9eb3-95d8c481cb30","type":"ColumnDataSource"},"glyph":{"id":"3869552f-1aa1-4fc2-a407-9c7990076065","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9cb23a8f-3c15-4e8c-8a43-2f48482676ff","type":"Line"},"selection_glyph":null},"id":"dedae722-a18f-4bae-b98c-930f984d42f4","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3869552f-1aa1-4fc2-a407-9c7990076065","type":"Line"},{"attributes":{"line_color":{"value":"#d62728"},"x":{"field":"x"},"y":{"field":"y"}},"id":"13eabb18-aa6e-4a1c-96d5-1a780ed818d7","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"beae101c-d8ae-4dc4-b7cb-3f0c3589f8a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1d8cf0f-99b7-400a-8ee7-733c8dab25b3","type":"BasicTicker"}},"id":"aafbe2da-fa14-4552-97c0-55c4bee50f91","type":"Grid"},{"attributes":{"overlay":{"id":"ff912ea6-c56e-4c21-8e95-38c08b258fd5","type":"BoxAnnotation"},"plot":{"id":"beae101c-d8ae-4dc4-b7cb-3f0c3589f8a5","subtype":"Figure","type":"Plot"}},"id":"975f2c6d-4f2c-44e6-8cd1-4298970e96f5","type":"BoxZoomTool"},{"attribu ...

# %% [markdown]
# These definitely look like functions of sorts but they look far too noisy to be useful for our purposes. Let's think a bit more about what we want from these samples and how we might change the distribution to get better looking samples...
#
# The multivariate Gaussian has two parameters, its mean and covariance matrix. If we changed the mean then we would only change the overall trend (i.e. if the mean was ascending integers, e.g. `np.arange(D)` then the samples would have an overall positive linear trend) but there would still be that jagged noisy shape. For this reason we tend to leave the GP mean as zero - they actually turn out to be powerful enough to model many functions without changing this.
#
# Instead we want some notion of _smoothness_: i.e. if two input points are close to each other then we expect the value of the function at those points to be similar. In terms of our model: random variables corresponding to nearby points should have similar values when sampled under their joint distribution (i.e. high _covariance_).
#
# The covariance of these points is defined in the covariance matrix of the Gaussian. Suppose we have an $N$ dimensional Gaussian modeling $y_0,\ldots, y_N$, then the covariance matrix $\Sigma$ is $N\times N$ and its $(i, j)$-th element is $\Sigma_{ij}=\text{cov}(y_i, y_j)$. In other words $\Sigma$ is symmetric and stores the pairwise covariances of all the jointly modeled random variables.
#
# ## Smoothing with Kernels
# ***
#
# So how should we define our covariance function? This is where the vast literature on kernels comes in handy. For our purposes we will choose a __squared exponential kernel__ which (in its simplest form) is defined by:
#
# $$ \kappa(x, x')=\exp\left(-~\frac{(x-x')^2}{2}\right)$$
#
# This function (which we plot in a moment) is 1 when $x=x'$ and tends to zero as its arguments drift apart.

# %%
def k(xs, ys, sigma=1, l=1):
    """Sqared Exponential kernel as above but designed to return the whole
    covariance matrix - i.e. the pairwise covariance of the vectors xs & ys.
    Also with two parameters which are discussed at the end."""

    # Pairwise difference matrix.
    dx = np.expand_dims(xs, 1) - np.expand_dims(ys, 0)
    return (sigma ** 2) * np.exp(-((dx / l) ** 2) / 2)

def m(x):
    """The mean function. As discussed, we can let the mean always be zero."""
    return np.zeros_like(x)

# %% [markdown]
# We can plot this kernel to show how it's maximised when $x=x'$ and then smoothly falls off as the two inputs start to differ.

# %%
N = 100
x = np.linspace(-2, 2, N)
y = np.linspace(-2, 2, N)
d = k(x, y)

color_mapper = LinearColorMapper(palette="Plasma256", low=0, high=1)

p = figure(plot_width=400, plot_height=400, x_range=(-2, 2), y_range=(-2, 2),
           title='Visualisation of k(x, x\')', x_axis_label='x', y_axis_label='x\'', toolbar_location=None)
p.image(image=[d], color_mapper=color_mapper, x=-2, y=-2, dw=4, dh=4)

color_bar = ColorBar(color_mapper=color_mapper, ticker=BasicTicker(),
                     label_standoff=12, border_line_color=None, location=(0,0))

p.add_layout(color_bar, 'right')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3fc5e657-5308-435d-ad40-24bd3b320c71"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3fc5e657-5308-435d-ad40-24bd3b320c71");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3fc5e657-5308-435d-ad40-24bd3b320c71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3fc5e657-5308-435d-ad40-24bd3b320c71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3aab4533-14e6-45e4-aaa0-828dd07b4d32":{"roots":{"references":[{"attributes":{},"id":"dd3e6797-29bf-41fa-8626-720d9ee98e9c","type":"BasicTicker"},{"attributes":{"high":1,"low":0,"palette":["#0C0786","#100787","#130689","#15068A","#18068B","#1B068C","#1D068D","#1F058E","#21058F","#230590","#250591","#270592","#290593","#2B0594","#2D0494","#2F0495","#310496","#330497","#340498","#360498","#380499","#3A049A","#3B039A","#3D039B","#3F039C","#40039C","#42039D","#44039E","#45039E","#47029F","#49029F","#4A02A0","#4C02A1","#4E02A1","#4F02A2","#5101A2","#5201A3","#5401A3","#5601A3","#5701A4","#5901A4","#5A00A5","#5C00A5","#5E00A5","#5F00A6","#6100A6","#6200A6","#6400A7","#6500A7","#6700A7","#6800A7","#6A00A7","#6C00A8","#6D00A8","#6F00A8","#7000A8","#7200A8","#7300A8","#7500A8","#7601A8","#7801A8","#7901A8","#7B02A8","#7C02A7","#7E03A7","#7F03A7","#8104A7","#8204A7","#8405A6","#8506A6","#8607A6","#8807A5","#8908A5","#8B09A4","#8C0AA4","#8E0CA4","#8F0DA3","#900EA3","#920FA2","#9310A1","#9511A1","#9612A0","#9713A0","#99149F","#9A159E","#9B179E","#9D189D","#9E199C","#9F1A9B","#A01B9B","#A21C9A","#A31D99","#A41E98","#A51F97","#A72197","#A82296","#A92395","#AA2494","#AC2593","#AD2692","#AE2791","#AF2890","#B02A8F","#B12B8F","#B22C8E","#B42D8D","#B52E8C","#B62F8B","#B7308A","#B83289","#B93388","#BA3487","#BB3586","#BC3685","#BD3784","#BE3883","#BF3982","#C03B81","#C13C80","#C23D80","#C33E7F","#C43F7E","#C5407D","#C6417C","#C7427B","#C8447A","#C94579
","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"0a49ea6c-c55a-456d-9f0d-0c836e2bc948","type":"Range1d"},"y_range":{"id":"d3adb2e2-7de8-4dfa-a930-b3fa322aafc1","type":"Range1d"}},"id":"dd38e9 ...

# %% [markdown]
# So, to get the sort of smoothness we want we will consider two random variables $y_i$ and $y_j$ plotted at $x_i$ and $x_j$ to have covariance $\text{cov}(y_i, y_j)=\kappa(x_i, x_j)$ - _the closer they are together the higher their covariance_.
#
# Using the kernel function from above we can get this matrix with `k(xs, xs)`. Now lets try plotting another 10 samples from the 20D Gaussian, but this time with the new covariance matrix. When we do this we get:

# %%
p = figure(plot_width=800, plot_height=500)
D = 20
xs = np.linspace(0, 1, D)
for color in Category10[10]:
    ys = np.random.multivariate_normal(m(xs), k(xs, xs))
    p.circle(xs, ys, size=3, color=color)
    p.line(xs, ys, line_width=1, color=color)

show(p)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: covariance is not positive-semidefinite.
#   """
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a76e6517-622d-419d-b9cf-69ff59ae128e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a76e6517-622d-419d-b9cf-69ff59ae128e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a76e6517-622d-419d-b9cf-69ff59ae128e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a76e6517-622d-419d-b9cf-69ff59ae128e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1433722e-c1e4-48cb-b413-dd7597f22455":{"roots":{"references":[{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"66f64c2d-24c0-4ba9-a7f9-2ab0c963215e","type":"PanTool"},{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"bc97d501-24d6-401d-b605-7e936300150b","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"28d3a0e8-f9ea-48a3-8df4-c062f8fe88f2","type":"ColumnDataSource"},"glyph":{"id":"6bba958d-0579-4033-8a57-3625eabdea45","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"44a047bf-16a4-4f63-a3a2-b81f09b591af","type":"Circle"},"selection_glyph":null},"id":"d1f04a3b-6332-4371-aa76-2c262c5cd04e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"6a7d86c8-aead-420f-a14d-5f32a63a7994","type":"ResetTool"},{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"40d4e86a-1778-4ac0-8fe8-49453dff63ca","type":"SaveTool"},{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3d962ea-9851-4250-a40c-d9c4c9419f9d","type":"BasicTicker"}},"id":"fcc4d2b6-011a-4632-9a4d-6fa192683b9b","type":"Grid"},{"attributes":{"overlay":{"id":"e05584ef-41c2-4040-96e1-036175c0b629","type":"BoxAnnotation"},"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"a8c2d4eb-7742-4e86-a2d5-bd84b725e9ad","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#ff7f0e"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a7626b2-c2af-4ebc-9cc3-7b4d0292b4bb","type":"Line"},{"attributes":{"data_source":{"id":"75cfe496-ef1e-466c-a7f3-49dcc942b24d","type":"ColumnDataSource"},"glyph":{"id":"1a7626b2-c2af-4ebc-9cc3-7b4d0292b4bb","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cd916d87-9bc0-43a0-8dbd-3a07d5a12a1f","type":"Line"},"selection_glyph":null},"id":"112210dd-1b37-44d9-b34a-0c026550b309","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"7990a10a-d340-4d79-9279-83d761b8cbb3","type":"Circle"},{"attributes":{"plot":{"id":"575eb073-fd07-43b1-8bda-b6739a2b57bb","subtype":"Figure","type":"Plot"}},"id":"38e54b99-d564-4779-8bac-dc1b2cb5972a","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"ukF1YJbP3b//hNCYKLDgv4dnCUunNOK/lgcWjC1047/9nJrJVG7kv37ld5VlI+W/Ogm6qVKU5b8Q0p3hssLlv75j+m+6sOW/+d1QNDNh5b/EjrIcdNfkv0JOiWdXF+S/1FfQtS8l47/gbvWKuwXiv+EoEikXvuC/3pnWLVmn3r+PNNjpQ5jbvxFHsMaLWti/BxKPy/T51L/vKB/YPILRvw==","dtype":"float64","shape":[20]}}},"id":"94cc04eb-1ddf-474f-af16-80a5d091be56","type":"ColumnDataSource"},{"attributes":{},"id":"25df505f-462d-48e4-a3d1-1961ef0ac133","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"615457cc-d73c-4c9f-9ed1-a574f0485c88","type":"Title"},{"attributes":{"line_color":{"value":"#2ca02c"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b561201e-a5e9-4350-ada6-db4081b9b329","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"yHvQ08t95787knni7iTov+eJ78NfoOi/DzqjDR/o6L8ZWTXB+PTov/ ...

# %% [markdown]
# Now we have something thats starting to look like a distribution over (useful) functions! And we can see how as the number of dimensions tends to infinity we don't have to connect points any more because we will have a point for every possible choice of input.
#
# Let's use more dimensions and see what it looks like across a bigger range of inputs:

# %%
n = 100
xs = np.linspace(-5, 5, n)
K = k(xs, xs, sigma=1, l=1)
mu = m(xs)

# %%
p = figure(plot_width=800, plot_height=500)

for color in Category10[5]:
    ys = np.random.multivariate_normal(mu, K)
    p.line(xs, ys, line_width=2, color=color)
show(p)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   after removing the cwd from sys.path.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd9394aa-e8d9-451d-809b-e78a264225c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cd9394aa-e8d9-451d-809b-e78a264225c1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd9394aa-e8d9-451d-809b-e78a264225c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd9394aa-e8d9-451d-809b-e78a264225c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ed7b19b6-8158-40a2-8aca-d31b4b64ac11":{"roots":{"references":[{"attributes":{"plot":{"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"}},"id":"2f461743-e739-4a40-bdc2-89694d2990a1","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f88fe465-ee67-41df-8abc-2b062c82228b","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e52b202-c399-484b-8f8d-7f2e19b4b181","type":"Line"},{"attributes":{"below":[{"id":"b8a516ab-c464-40d7-b3ae-9e90b8a566f9","type":"LinearAxis"}],"left":[{"id":"ae988107-4737-4a0b-ab24-1a274f790b51","type":"LinearAxis"}],"plot_height":500,"plot_width":800,"renderers":[{"id":"b8a516ab-c464-40d7-b3ae-9e90b8a566f9","type":"LinearAxis"},{"id":"55cc22a9-e7c3-4979-96cb-dc02ebe93a71","type":"Grid"},{"id":"ae988107-4737-4a0b-ab24-1a274f790b51","type":"LinearAxis"},{"id":"197205ed-2fc7-4e09-a3b1-26b0cbb0b2dd","type":"Grid"},{"id":"f88fe465-ee67-41df-8abc-2b062c82228b","type":"BoxAnnotation"},{"id":"b471e959-7cda-4b7b-a889-6afa6ca23828","type":"GlyphRenderer"},{"id":"efbb6ff1-9d9c-48f2-8283-645ac6fbaa3e","type":"GlyphRenderer"},{"id":"8420fa6c-5c3d-40f4-8a79-1f33e6df5cf6","type":"GlyphRenderer"},{"id":"d6ce10de-3208-492c-b9d3-26a115da5d8f","type":"GlyphRenderer"},{"id":"eefe2e28-8258-43f5-b18d-042dfc0ba2ae","type":"GlyphRenderer"}],"title":{"id":"5ad04f4c-bc8e-420c-8222-ac1e4209cdf1","type":"Title"},"tool_events":{"id":"32eb4922-e606-4830-9818-c5c92cc22ce7","type":"ToolEvents"},"toolbar":{"id":"0899c61e-5365-4da4-97a3-9d56a06e9f3a","type":"Toolbar"},"x_range":{"id":"73cfab4a-0780-460a-9ea5-79801baa8709","type":"DataRange1d"},"y_range":{"id":"ec7ebbf8-d2b0-4071-82d8-68e1f173403d","type":"DataRange1d"}},"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"}},"id":"969ae85b-aa95-497f-ac42-f50348484972","type":"SaveTool"},{"attributes":{"callback":null},"id":"73cfab4a-0780-460a-9ea5-79801baa8709","type":"DataRange1d"},{"attributes":{"callback":null},"id":"ec7ebbf8-d2b0-4071-82d8-68e1f173403d","type":"DataRange1d"},{"attributes":{"plot":{"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"}},"id":"5f89fddb-4261-4124-a612-da0dfbb869f9","type":"HelpTool"},{"attributes":{"plot":{"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"}},"id":"f9fb1381-aa0b-49dd-919d-c4c98497b9f8","type":"PanTool"},{"attributes":{"plot":{"id":"4a09891b-e353-4963-87fc-6faa77f1115e","subtype":"Figure","type":"Plot"}},"id":"dc1a1212-515d-4256-bfa3-b2d372aa0371","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"d9ab9023-415f-4bdb-b529-1166a1839794","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f9fb1381-aa0b-49dd-919d-c4c98497b9f8","type":"PanTool"},{"id":"2f461743-e739-4a40-bdc2-89694d2990a1","type":"WheelZoomTool"},{"id":"eb24eb34-f8bb-49a8-8174-ce2762fd52eb","type":"BoxZoomTool"},{"id":"969ae85b-aa95-497f-ac42-f50348484972","type":"SaveTool"},{"id":"dc1a1212-515d-4256-bfa3-b2d372aa0371","type":"ResetTool"},{"id":"5f89fddb-4261-4124-a612-da0dfbb869f9","type":"HelpTool"}]},"id":"0899c61e-5365-4da4-97a3-9d56a06e9f3a","type":"Toolbar"},{"attributes":{"line_color":{"value":"#ff7f0e"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e734b75-90fb-4777-8e2b-c0703d7c17f3","type":"Line ...

# %% [markdown]
# ## Making Predictions using the Prior & Observations
# ***
# Now that we have a distribution over functions, how can we use training data to model a hidden function so that we can make predictions?
#
# First of all we need some training data! And to get that we are going to create our secret function $f$.
#
# ### The Target Function $f$
# For this intro we'll use a 5th order polynomial:
#
# $$f(x)=0.03 x^5 + 0.2 x^4 - 0.1 x^3 - 2.4 x^2 - 2.5 x + 6$$
#
# I chose this because it has a nice wiggly graph but we could have chosen anything (try changing `coefs` below, or `f(x)` entirely, to model different functions).

# %%
# coefs[i] is the coefficient of x^i
coefs = [6, -2.5, -2.4, -0.1, 0.2, 0.03]

def f(x):
    total = 0
    for exp, coef in enumerate(coefs):
        total += coef * (x ** exp)
    return total

# %%
xs = np.linspace(-5.0, 3.5, 100)
ys = f(xs)

# %%
p = figure(plot_width=800, plot_height=400, x_axis_label='x', y_axis_label='f(x)',
           title='The hidden function f(x)')
p.line(xs, ys, line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8bc41a67-04d7-4e49-b61d-0ea356a0b132"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8bc41a67-04d7-4e49-b61d-0ea356a0b132");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8bc41a67-04d7-4e49-b61d-0ea356a0b132");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8bc41a67-04d7-4e49-b61d-0ea356a0b132' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5d23ac2c-f3a3-43c5-9b0f-7681221d3fbe":{"roots":{"references":[{"attributes":{"axis_label":"x","formatter":{"id":"b35cdc83-017f-4174-905e-b8770ee11ab4","type":"BasicTickFormatter"},"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"},"ticker":{"id":"03102230-bdf0-4699-b874-641348636df1","type":"BasicTicker"}},"id":"f3ef8d2b-18a7-4672-8b13-e0b0136213cb","type":"LinearAxis"},{"attributes":{"data_source":{"id":"0e3f7191-8ef2-418a-9fb3-3124ed9f657b","type":"ColumnDataSource"},"glyph":{"id":"7c50ac74-3365-489c-9301-e9612fa8c579","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3b88cd43-f9a5-4545-b737-8bbe2037329a","type":"Line"},"selection_glyph":null},"id":"e83f64d2-7720-44ec-b630-48a9a0492ded","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"}},"id":"70be432a-c481-4fbb-b0bb-ddf5eb0210d8","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3b88cd43-f9a5-4545-b737-8bbe2037329a","type":"Line"},{"attributes":{"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"},"ticker":{"id":"03102230-bdf0-4699-b874-641348636df1","type":"BasicTicker"}},"id":"0851624c-f76f-40cd-b455-c876dbf6cb91","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e88dbebb-e2f7-4734-ab10-034f62020a53","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"}},"id":"56f3d63e-50aa-45ab-84ec-55a705e90e86","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"}},"id":"c4466831-503b-4697-82db-de2e8e61e839","type":"ResetTool"},{"attributes":{},"id":"b35cdc83-017f-4174-905e-b8770ee11ab4","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c50ac74-3365-489c-9301-e9612fa8c579","type":"Line"},{"attributes":{},"id":"d84a22eb-0084-4c5a-8e8e-98884d43d17d","type":"ToolEvents"},{"attributes":{"overlay":{"id":"e88dbebb-e2f7-4734-ab10-034f62020a53","type":"BoxAnnotation"},"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"}},"id":"b43b184b-010f-462f-998b-109bc7337a0f","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b61bd4a-e3af-465e-99ef-fd844c2da220","type":"BasicTicker"}},"id":"c59cb6d8-ac64-44c5-970f-a4c6a5ae4d25","type":"Grid"},{"attributes":{"plot":{"id":"8dda7ef5-e9ba-4f2b-b745-c7e14f67b84c","subtype":"Figure","type":"Plot"}},"id":"229da1b4-f37e-40f8-9a8a-a54811c30ac5","type":"SaveTool"},{"attributes":{},"id":"0385a55e-0014-476e-9733-b841362e8591","type":"BasicTickFormatter"},{"attributes":{},"id":"3b61bd4a-e3af-465e-99ef-fd844c2da220","type":"BasicTicker"},{"attributes":{"below":[{"id":"f3ef8d2b-18a7-4672-8b13-e0b0136213cb","type":"LinearAxis"}],"left":[{"id":"48db9f31-2a48-4184-a2c5-1823db4c8b4d","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"f3ef8d2b-18a7-4672-8b13-e0b0136213cb","type":"LinearAxis"},{"id":"0851624c-f76f-40cd-b455-c876dbf6cb91","type":"Grid"},{"id":"48db9f31-2a48-4184-a2c5-1823db4c8b4d","type":"LinearAxis"},{"id":"c59cb6d8-ac64-44c5-970f-a4c6a5ae4d25","type":"Grid"},{"id":"e88dbebb-e2f7-4734-ab10-034f62020a53","type":"BoxAnnotation"},{"id":"e83f64d2-7720-44ec-b630-48a9a0492ded","type":"GlyphRenderer"}],"title":{"id":"56731793-ad6c-4f93-92e2-61314289273b","type":"Title"},"tool_event ...

# %% [markdown]
# ### Getting into the Maths
#
# Now we get to the heart of GPs. Theres a bit more maths required but it only consists of consolidating what we have so far and using one trick to condition our joint distribution on observed data.
#
# So far we have a way to model $p(\mathbf{y}\vert\mathbf{x})$ using a multivariate normal:
#
# $$p(\mathbf{y}\vert\mathbf{x})=\mathcal{N}(\mathbf{y}\vert m(\mathbf{x}),\mathbf{K})$$
#
# where $\mathbf{K}=\kappa(\mathbf{x}, \mathbf{x})$ and $m(\mathbf{x})=\mathbf{0}$.
#
# This is a prior distribution representing the kind out outputs $\mathbf{y}$ that we expect to see over some inputs $\mathbf{x}$ _before_ we observe any data.
#
# So we have some training data with inputs $\mathbf{x}$, and outputs $\mathbf{y}=f(\mathbf{x})$. Now lets say we have some new points $\mathbf{x}_*$ where we want to predict $\mathbf{y}_*=f(\mathbf{x}_*)$.

# %%
x_obs = np.array([-4, -1.5, 0, 1.5, 2.5, 2.7])
y_obs = f(x_obs)

x_s = np.linspace(-8, 7, 80)

# %% [markdown]
# Now recalling the definition of a GP, we will model the joint distribution of all of $\mathbf{y}$ and $\mathbf{y}_*$ as:
#
# $$ \begin{pmatrix}\mathbf{y} \\ \mathbf{y}_*\end{pmatrix} \sim\mathcal{N}\left(\begin{pmatrix}m(\mathbf{x})\\ m(\mathbf{x}_*)\end{pmatrix}, \begin{pmatrix}\mathbf{K} & \mathbf{K}_* \\ \mathbf{K}_*^T & \mathbf{K}_{**}\end{pmatrix}\right) $$
#
# where $\mathbf{K}=\kappa(\mathbf{x}, \mathbf{x})$, $\mathbf{K}_* = \kappa(\mathbf{x}, \mathbf{x}_*)$ and $\mathbf{K}_{**}=\kappa(\mathbf{x}_*, \mathbf{x}_*)$. As before we are going to stick with a zero mean.
#
# However this is modeling $p(\mathbf{y}, \mathbf{y}_*\vert \mathbf{x}, \mathbf{x}_*)$ and we only want a distribution over $\mathbf{y}_*$!
#
# ### Conditioning Multivariate Gaussians
#
# Rather than deriving it from scratch we can just make use of [this standard result](https://en.wikipedia.org/wiki/Multivariate_normal_distribution#Conditional_distributions). If we have a joint distribution over $\mathbf{y}$ and $\mathbf{y}_*$ as above, and we want to condition on the data we have for $\mathbf{y}$ then we have the following:
#
# $$\begin{align}
# p(\mathbf{y}_*\vert \mathbf{x}_*, \mathbf{x}, \mathbf{y})&=\mathcal{N}(\mathbf{y}_*\vert \mu_*, \Sigma_*)\\
# \mu_*&=m(\mathbf{x}_*)+\mathbf{K}_*^T\mathbf{K}^{-1}(\mathbf{y}-m(\mathbf{x}))\\
# \Sigma_*&=\mathbf{K}_{**}-\mathbf{K}_*^T\mathbf{K}^{-1}\mathbf{K}_*
# \end{align}$$
#
# Now we have a posterior distribution over $\mathbf{y}_*$ using a prior distribution and some observations!
#
# _NB: The code below would not be used in practice since \\( \mathbf{K} \\) can often be poorly conditioned, so its inverse might be inaccurate. A better approach is covered in part II of this guide!_

# %%
K = k(x_obs, x_obs)
K_s = k(x_obs, x_s)
K_ss = k(x_s, x_s)

K_sTKinv = np.matmul(K_s.T, np.linalg.pinv(K))

mu_s = m(x_s) + np.matmul(K_sTKinv, y_obs - m(x_obs))
Sigma_s = K_ss - np.matmul(K_sTKinv, K_s)

# %% [markdown]
# And that's it! We can now use these two parameters to draw samples from the conditional distribution. Here we plot them against the true function $f(x)$ (the dashed black line). Since we are using a GP we also have uncertainty information in the form of the variance of each random variable. We know the variance of the $i$-th will be ${\Sigma_*}_{ii}$ - in other words the variances are just the diagonal elements of $\Sigma_*$. Here we plot the samples with an uncertainty of $\pm 2$ standard deviations.

# %%
p = figure(plot_width=800, plot_height=600, y_range=(-7, 8))

y_true = f(x_s)
p.line(x_s, y_true, line_width=3, color='black', alpha=0.4, line_dash='dashed', legend='True f(x)')

p.cross(x_obs, y_obs, size=20, legend='Training data')

stds = np.sqrt(Sigma_s.diagonal())
err_xs = np.concatenate((x_s, np.flip(x_s, 0)))
err_ys = np.concatenate((mu_s + 2 * stds, np.flip(mu_s - 2 * stds, 0)))
p.patch(err_xs, err_ys, alpha=0.2, line_width=0, color='grey', legend='Uncertainty')

for color in Category10[3]:
    y_s = np.random.multivariate_normal(mu_s, Sigma_s)
    p.line(x_s, y_s, line_width=1, color=color)
    
p.line(x_s, mu_s, line_width=3, color='blue', alpha=0.4, legend='Mean')
show(p)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: covariance is not positive-semidefinite.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4c9611a3-1031-4bd7-93b6-844341962ec5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4c9611a3-1031-4bd7-93b6-844341962ec5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c9611a3-1031-4bd7-93b6-844341962ec5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c9611a3-1031-4bd7-93b6-844341962ec5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"323ff561-d4a8-41d4-9837-b7cd8349949a":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"grey"},"line_alpha":{"value":0.2},"line_color":{"value":"grey"},"line_width":{"value":0},"x":{"field":"x"},"y":{"field":"y"}},"id":"2ea496e6-5b3d-4ceb-b0d8-54fd0778eec6","type":"Patch"},{"attributes":{"below":[{"id":"67e6735b-852d-43e4-af4f-12b285f49430","type":"LinearAxis"}],"left":[{"id":"5a1ce1b6-60c5-4b9f-a02b-3efc9fd0de06","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"67e6735b-852d-43e4-af4f-12b285f49430","type":"LinearAxis"},{"id":"fbeae69f-1509-4301-a375-53b28d85657a","type":"Grid"},{"id":"5a1ce1b6-60c5-4b9f-a02b-3efc9fd0de06","type":"LinearAxis"},{"id":"7bac8f23-2cfb-4d16-82d4-3708b75e466a","type":"Grid"},{"id":"45db020f-3781-4dd2-936d-f46fe8d5af90","type":"BoxAnnotation"},{"id":"c3632ce9-2bc7-4f57-b68f-5b2f782eac60","type":"Legend"},{"id":"8c2f4841-2188-4985-af25-ef8fb0c2d258","type":"GlyphRenderer"},{"id":"cd0f5cea-2359-4d75-b496-e60a26a1aee3","type":"GlyphRenderer"},{"id":"b28bf115-b005-49df-915f-35680063b7d6","type":"GlyphRenderer"},{"id":"7553f059-da38-46e1-a84f-d60c5eec537d","type":"GlyphRenderer"},{"id":"56164b2e-7a1f-471d-a9ec-7e5e21b2151c","type":"GlyphRenderer"},{"id":"708d471f-e6bf-42f7-b8b3-c074e6761fb0","type":"GlyphRenderer"},{"id":"9bdae26a-e0ee-4754-aa82-483d49ca585f","type":"GlyphRenderer"}],"title":{"id":"30cc0d69-d4b7-4b99-9859-df10259f384c","type":"Title"},"tool_events":{"id":"52f2e004-fe0f-4680-9409-26257011af4b","type":"ToolEvents"},"toolbar":{"id":"5805d1e7-03f9-4255-98d3-093b331de63b","type":"Toolbar"},"x_range":{"id":"07c67eba-a5dc-435d-a031-f88676789a81","type":"DataRange1d"},"y_range":{"id":"bf650745-5960-49bf-9fbb-04c999ab7273","type":"Range1d"}},"id":"d3b973db-082d-40c8-8f96-4eb70f64fc89","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"9b9eaf7f-9dbd-4b6c-838d-ba2a976151fe","type":"ColumnDataSource"},"glyph":{"id":"d10ff5c4-7697-4442-9cfe-9a156682dbd9","type":"Cross"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"737664a5-a6c4-470e-9737-da2beba0fa8a","type":"Cross"},"selection_glyph":null},"id":"cd0f5cea-2359-4d75-b496-e60a26a1aee3","type":"GlyphRenderer"},{"attributes":{},"id":"52f2e004-fe0f-4680-9409-26257011af4b","type":"ToolEvents"},{"attributes":{"callback":null},"id":"07c67eba-a5dc-435d-a031-f88676789a81","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4ec2863f-76ee-4910-9d06-7dd4bd5f18c3","type":"PanTool"},{"id":"66037866-cda8-4d7a-8dea-f07c7a63b150","type":"WheelZoomTool"},{"id":"c9c88a95-f819-4973-b91b-1ace9a5fd6d4","type":"BoxZoomTool"},{"id":"f248c4ed-f06b-46f3-8a4a-ac950bb137dd","type":"SaveTool"},{"id":"91f5c195-5efe-4afc-8669-27f02f767feb","type":"ResetTool"},{"id":"c580c1c6-516d-4f40-89a5-c9bfb8095ad8","type":"HelpTool"}]},"id":"5805d1e7-03f9-4255-98d3-093b331de63b","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"737664a5-a6c4-470e-9737-da2beba0fa8a","type":"Cross"},{"attributes":{"callback":null,"end":8,"start":-7},"id":"bf650745-5960-49bf-9fbb-04c999ab7273","type":"Range1d"},{"attributes":{"formatter":{"id":"207a6da7-2b25-4ebe-8733-b3787ea166ac","type":"BasicTickFormatter"},"plot":{"id":"d3b973db-082d-40c8-8f96-4eb70f64fc89","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f77f547-63bd-4503-aceb-5de85a2562d5","type":"BasicTicker"}},"id":"67e6735b-852d-43e4-af4f-12b285f49430","type":"LinearAxis"},{"attributes":{"label":{"value":"True f(x)"},"renderers":[{"id":"8c2f4841-2188-4985-af25-ef8fb0c2d258","type":"GlyphRenderer"}]},"id":"809cafab-3d6f-4d11-8e37-c0951870c1ea","type":"LegendItem"},{"attributes":{},"id":"1f77f547-63bd-4503-aceb-5de85a2562d5","type":"BasicTicker"},{"attributes":{"plot":{"id":"d3b973db-082d-40c8-8 ...

# %% [markdown]
# ## What next? - GP Regression and Noisy Data
# ***
# In practice we need to do a bit more work to get good predictions. You may have noticed that the kernel implementation contained two parameters $\sigma$ and $l$. If you try changing those when sampling from the prior then you can see how $\sigma$ changes the vertical variation and $l$ changes the horizontal scale. So we would need to change these to reflect our prior belief about the hidden function $f$. For instance if we expect $f$ to have a much bigger range of outputs (for the domain we are interested in) then we would need to scale up $\sigma$ accordingly (try scaling the return value of $f$ by 100 to see what happens, then set `sigma=100`). In fact, as with anything that uses kernels, we might change our kernel entirely if we expect a different kind of function (e.g. a periodic function).
#
# Picking the kernel is up to a human expert but choosing the parameters can be done automatically by minimising a loss term. This is the realm of Gaussian process regression.
#
# Finally we should consider how to handle noisy data - i.e. when we can't get perfect samples of the hidden function $f$. In this case we need to factor this uncertainty into the model to get better generalisation.
#
# These two topics will be the focus of _Introduction to Gaussian Processes - Part II_.

# %% [markdown]
# ## Resources
# ***
# - _Machine Learning - A Probabilistic Perspective_, Chapter 15 by Kevin P. Murphy
# - [Introduction to Gaussian processes](https://www.youtube.com/watch?v=4vGiHC35j9s) on YouTube by Nando de Freitas
